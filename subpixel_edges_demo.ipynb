# %% [markdown]
# # Demo of the `subpixel-edges` package

# %% [markdown]
# ## Installing the package

# %%
# !pip install subpixel-edges

# %% [markdown]
# ## Installing the other dependencies

# %%
# !pip install opencv-python
# !pip install matplotlib

# %% [markdown]
# ## Running a minimal example

# %%
import cv2
import matplotlib.pyplot as plt

from subpixel_edges import subpixel_edges

# %%
# Load the image and convert it to grayscale
img = cv2.imread("lena.png")
img_gray = (cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)).astype(float)

# Extract the edges
edges = subpixel_edges(img_gray, 25, 0, 2)

# %%
# Plot the grayscale image without and with the edges
plt.figure(figsize=(12, 9))

plt.subplot(121)
plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)

plt.subplot(122)
plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)
plt.quiver(edges.x, edges.y, edges.nx, -edges.ny, scale=40)

plt.show()
